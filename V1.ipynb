# %% [markdown]
# # V1: Base Model
#
# Methodology:
# - Distilbert model (open source huggingface)
# - SNP 5.3GB dataset (news) -> identified only top 15 tickers in weight
# - Generate predictions for each Article title
# - Group by day, and create a score (sum) for each day
# - Optimise to find a threshold, if above buy if below sell.
# - To test for buy sell amount

# %%
import pandas as pd

read_df = pd.read_csv('data/FNSPID dataset/snp 5.3gb.csv')

# %%
selected_symbols = ['MSFT', 'NVDA', 'AAPL', 'AMZN', 'META', 'AVGO', 'BRK.B', 'TSLA', 'GOOG', 'GOOGL', 'WMT', 'JPM', 'LLY', 'V', 'ORCL', 'NFLX', 'XOM', 'MA', 'COST', 'PG']

read_df = read_df[read_df['Stock_symbol'].isin(selected_symbols)]

# %%
df = pd.DataFrame({
    'Date': read_df['Date'],
    'Title': read_df['Article_title'],
    'StockSymbol': read_df['Stock_symbol']
})

df['Date'] = pd.to_datetime(df['Date'], utc=True).dt.date

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    if not isinstance(text, str) or text is None:
        return ""
    tokens = word_tokenize(text.lower())  # Tokenize and lowercase
    cleaned_tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha() and token not in stop_words]
    test_sentence = " ".join(cleaned_tokens)
    return test_sentence

# %%
df['Title'] = df['Title'].apply(preprocess)

# %%
from transformers import pipeline, set_seed
set_seed(999)

# %%
classifier = pipeline('sentiment-analysis', model='distilbert-base-uncased-finetuned-sst-2-english')

# %%
predictions = classifier(df['Title'].tolist())

df['Sentiment'] = [
    pred['score'] if pred['label'] == 'POSITIVE' else -pred['score'] if pred['label'] == 'NEGATIVE' else 0
    for pred in predictions
]

# %%
grouped_data = df.groupby('Date').agg({
    'Sentiment': 'sum'
})
grouped_data.index = pd.to_datetime(grouped_data.index)
grouped_data.to_csv('data/grouped_data/V1 grp_df.csv')

# %%
# import yfinance as yf
#
# # Download OHLCV data for SPY (adjust ticker as needed)
# price_data = yf.download('AAPL', start='2008-08-20', end='2011-06-30')
#
# if isinstance(price_data.columns, pd.MultiIndex):
#     price_data.columns = price_data.columns.droplevel(1)
# price_data.reset_index(inplace=True)  # Move Date to a column
# price_data['Date'] = pd.to_datetime(price_data['Date']).dt.strftime('%Y-%m-%d')
#
# # Save to CSV with clean format
# price_data.to_csv('data/Training Data/SNP 08-11.csv', index=False)

# %%
import pandas as pd
grouped_data = pd.read_csv('data/grouped_data/V1 grp_df.csv', index_col='Date')
grouped_data.index = pd.to_datetime(grouped_data.index)

# %%
# # optimise threshold
# cerebro.optstrategy(SentimentStrategy, sentiment_threshold=[0.0, 0.5, 1.0])
#
# # Set initial cash
# cerebro.broker.setcash(1000000.0)
#
# # Add commission (e.g., 0.1% per trade)
# cerebro.broker.setcommission(commission=0.001)
#
# # Run backtest
# results = cerebro.run()
#
# for strategy in results:
#     print('Sentiment Threshold:', strategy.params.sentiment_threshold)
#     print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

# %%
import backtrader as bt

# Initialize Cerebro
cerebro = bt.Cerebro()

# Load price data
price_feed = bt.feeds.YahooFinanceCSVData(
    dataname='data/Training Data/SNP 08-11.csv',
    fromdate=pd.to_datetime('2009-08-07'),
    todate=pd.to_datetime('2010-06-10'),
    datetime=0,  # Date is first column
    open=1,
    high=2,
    low=3,
    close=4,
    volume=5,
    dateformat='%Y-%m-%d'
)
cerebro.adddata(price_feed, name='price')

# Load sentiment data
sentiment_feed = SentimentData(
    dataname=grouped_data,
    datetime=None,  # Use index as datetime
    sentiment='Sentiment',
    fromdate=pd.to_datetime('2009-08-07'),
    todate=pd.to_datetime('2010-06-10')
)
cerebro.adddata(sentiment_feed, name='sentiment')

class SentimentData(bt.feeds.PandasData):
    lines = ('sentiment',)
    params = (('sentiment', 'Sentiment'), ('datetime', None))

class SentimentStrategy(bt.Strategy):
    params = (
        ('size', 100),  # Number of shares to trade
        ('sentiment_threshold', 0.2),  # Threshold for sentiment signal
    )

    def __init__(self):
        self.sentiment = self.datas[1].sentiment  # Access sentiment line explicitly
        self.order = None
        self.last_date = None  # Track last processed date

    def next(self):
        date = self.datas[0].datetime.date(0)
        if self.last_date == date:
            return
        sentiment = self.sentiment[0]
        print(f"{date}: Sentiment={sentiment}, Close={self.datas[0].close[0]}, Position={self.position.size}, OrderPending={self.order is not None}")

        if self.order:
            self.close()
            print(f'{date}: Close')

        if sentiment > self.params.sentiment_threshold:
            self.order = self.buy(size=int(self.params.size))
            print(f"{date}: Buy {self.params.size} shares at {self.datas[0].close[0]}")
        elif sentiment < -self.params.sentiment_threshold:
            self.order = self.sell(size=int(self.params.size))
            print(f"{date}: Sell {self.params.size} shares at {self.datas[0].close[0]}")
        else:
            print(f"{date}: No trade (Sentiment={sentiment} within threshold)")

        self.last_date = date  # Update last processed date

class DebugStrategy(bt.Strategy):
    params = (
        ('size', 100),  # Number of shares to trade
        ('sentiment_threshold', 0.5),  # Threshold for sentiment signal
    )

    def __init__(self):
        self.sentiment = self.datas[1].sentiment  # Access sentiment line explicitly
        self.order = None
        self.last_date = None  # Track last processed date

    def next(self):
        date = self.datas[0].datetime.date(0)
        if self.last_date == date:
            return
        sentiment = self.sentiment[0]
        print(f'{date}: {sentiment}, {self.last_date}')
        self.last_date = date

# %%
# Add strategy
cerebro.addstrategy(SentimentStrategy, size=1, sentiment_threshold=0.5)

initial_cash = 100000
commission = 0.001

# Set initial cash
cerebro.broker.setcash(initial_cash)

# Add commission (e.g., 0.1% per trade)
cerebro.broker.setcommission(commission=commission)

# Add analyzers
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')
cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='trades')

# Run backtest
results = cerebro.run()
strategy = results[0]

# Print results
print(strategy.analyzers.sharpe.get_analysis())
print(strategy.analyzers.returns.get_analysis())
print(f'Initial Portfolio Value: %.2f {initial_cash}, commission: {commission}')
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
print('Sharpe Ratio:', strategy.analyzers.sharpe.get_analysis()['sharperatio'])
print('Total Return:', strategy.analyzers.returns.get_analysis()['rtot'])
trade_analysis = strategy.analyzers.trades.get_analysis()
print('Total Trades:', trade_analysis['total']['total'])

# Plot results
# cerebro.plot()
# Out:
# 2009-08-07: Sentiment=4.878258645534515, Close=387354800.0, Position=0, OrderPending=False
# 2009-08-07: Buy 1 shares at 387354800.0
# 2009-08-07: Sentiment=4.878258645534515, Close=387354800.0, Position=0, OrderPending=False
# 2009-08-07: Buy 1 shares at 387354800.0
# 2009-08-07: Sentiment=4.878258645534515, Close=387354800.0, Position=0, OrderPending=False
# 2009-08-07: Buy 1 shares at 387354800.0
# 2009-08-07: Sentiment=4.878258645534515, Close=387354800.0, Position=0, OrderPending=False
# 2009-08-07: Buy 1 shares at 387354800.0
# 2009-08-10: Sentiment=-1.0101189613342283, Close=300294400.0, Position=0, OrderPending=True
# 2009-08-10: Close
# 2009-08-10: Sell 1 shares at 300294400.0
# 2009-08-10: Sentiment=-1.0101189613342283, Close=300294400.0, Position=0, OrderPending=True
# 2009-08-10: Close
# 2009-08-10: Sell 1 shares at 300294400.0
# 2009-08-10: Sentiment=-1.0101189613342283, Close=300294400.0, Position=0, OrderPending=True
# 2009-08-10: Close
# 2009-08-10: Sell 1 shares at 300294400.0
# 2009-08-10: Sentiment=-1.0101189613342283, Close=300294400.0, Position=0, OrderPending=True
# 2009-08-10: Close
# 2009-08-10: Sell 1 shares at 300294400.0
# 2009-08-11: Sentiment=0.9516351819038392, Close=355342400.0, Position=-4, OrderPending=True
# 2009-08-11: Close
# 2009-08-11: Buy 1 shares at 355342400.0
# 2009-08-11: Sentiment=0.9516351819038392, Close=355342400.0, Position=-4, OrderPending=True
# 2009-08-11: Close
# 2009-08-11: Buy 1 shares at 355342400.0
# 2009-08-11: Sentiment=0.9516351819038392, Close=355342400.0, Position=-4, OrderPending=True
# 2009-08-11: Close
# 2009-08-11: Buy 1 shares at 355342400.0
# 2009-08-11: Sentiment=0.9516351819038392, Close=355342400.0, Position=-4, OrderPending=True
# 2009-08-11: Close
# 2009-08-11: Buy 1 shares at 355342400.0
# 2009-08-12: Sentiment=4.025720000267029, Close=445071200.0, Position=-4, OrderPending=True
# 2009-08-12: Close
# 2009-08-12: Buy 1 shares at 445071200.0
# 2009-08-12: Sentiment=4.025720000267029, Close=445071200.0, Position=-4, OrderPending=True
# 2009-08-12: Close
# 2009-08-12: Buy 1 shares at 445071200.0
# 2009-08-12: Sentiment=4.025720000267029, Close=445071200.0, Position=-4, OrderPending=True
# 2009-08-12: Close
# 2009-08-12: Buy 1 shares at 445071200.0
# 2009-08-12: Sentiment=4.025720000267029, Close=445071200.0, Position=-4, OrderPending=True
# 2009-08-12: Close
# 2009-08-12: Buy 1 shares at 445071200.0
# 2009-08-13: Sentiment=3.930560410022736, Close=439980800.0, Position=-4, OrderPending=True
# 2009-08-13: Close
# 2009-08-13: Buy 1 shares at 439980800.0
# 2009-08-13: Sentiment=3.930560410022736, Close=439980800.0, Position=-4, OrderPending=True
# 2009-08-13: Close
# 2009-08-13: Buy 1 shares at 439980800.0
# 2009-08-13: Sentiment=3.930560410022736, Close=439980800.0, Position=-4, OrderPending=True
# 2009-08-13: Close
# 2009-08-13: Buy 1 shares at 439980800.0
# 2009-08-13: Sentiment=3.930560410022736, Close=439980800.0, Position=-4, OrderPending=True
# 2009-08-13: Close
# 2009-08-13: Buy 1 shares at 439980800.0
# 2009-08-14: Sentiment=3.930560410022736, Close=305816000.0, Position=-4, OrderPending=True
# 2009-08-14: Close
# 2009-08-14: Buy 1 shares at 305816000.0
# 2009-08-14: Sentiment=3.930560410022736, Close=305816000.0, Position=-4, OrderPending=True
# 2009-08-14: Close
# 2009-08-14: Buy 1 shares at 305816000.0
# 2009-08-14: Sentiment=3.930560410022736, Close=305816000.0, Position=-4, OrderPending=True
# 2009-08-14: Close
# 2009-08-14: Buy 1 shares at 305816000.0
# 2009-08-14: Sentiment=3.930560410022736, Close=305816000.0, Position=-4, OrderPending=True
# 2009-08-14: Close
# 2009-08-14: Buy 1 shares at 305816000.0
# 2009-08-17: Sentiment=3.930560410022736, Close=524381200.0, Position=0, OrderPending=True
# 2009-08-17: Close
# 2009-08-17: Buy 1 shares at 524381200.0
# 2009-08-17: Sentiment=3.930560410022736, Close=524381200.0, Position=0, OrderPending=True
# 2009-08-17: Close
# 2009-08-17: Buy 1 shares at 524381200.0
# 2009-08-17: Sentiment=3.930560410022736, Close=524381200.0, Position=0, OrderPending=True
# 2009-08-17: Close
# 2009-08-17: Buy 1 shares at 524381200.0
# 2009-08-17: Sentiment=3.930560410022736, Close=524381200.0, Position=0, OrderPending=True
# 2009-08-17: Close
# 2009-08-17: Buy 1 shares at 524381200.0
# 2009-08-18: Sentiment=3.930560410022736, Close=431152400.0, Position=0, OrderPending=True
# 2009-08-18: Close
# 2009-08-18: Buy 1 shares at 431152400.0
# 2009-08-18: Sentiment=3.930560410022736, Close=431152400.0, Position=0, OrderPending=True
# 2009-08-18: Close
# 2009-08-18: Buy 1 shares at 431152400.0
# 2009-08-18: Sentiment=3.930560410022736, Close=431152400.0, Position=0, OrderPending=True
# 2009-08-18: Close
# 2009-08-18: Buy 1 shares at 431152400.0
# 2009-08-18: Sentiment=3.930560410022736, Close=431152400.0, Position=0, OrderPending=True
# 2009-08-18: Close
# 2009-08-18: Buy 1 shares at 431152400.0
# 2009-08-19: Sentiment=3.930560410022736, Close=413271600.0, Position=0, OrderPending=True
# 2009-08-19: Close
# 2009-08-19: Buy 1 shares at 413271600.0
# 2009-08-19: Sentiment=3.930560410022736, Close=413271600.0, Position=0, OrderPending=True
# 2009-08-19: Close
# 2009-08-19: Buy 1 shares at 413271600.0
# 2009-08-19: Sentiment=3.930560410022736, Close=413271600.0, Position=0, OrderPending=True
# 2009-08-19: Close
# 2009-08-19: Buy 1 shares at 413271600.0
# 2009-08-19: Sentiment=3.930560410022736, Close=413271600.0, Position=0, OrderPending=True
# 2009-08-19: Close
# 2009-08-19: Buy 1 shares at 413271600.0
# 2009-08-20: Sentiment=3.930560410022736, Close=342031200.0, Position=0, OrderPending=True
# 2009-08-20: Close
# 2009-08-20: Buy 1 shares at 342031200.0
# 2009-08-20: Sentiment=3.930560410022736, Close=342031200.0, Position=0, OrderPending=True
# 2009-08-20: Close
# 2009-09-10: Sentiment=-1.9281272292137144, Close=491134000.0, Position=-3, OrderPending=True
# 2009-09-10: Close
# 2009-09-10: Sell 1 shares at 491134000.0
# 2009-09-10: Sentiment=-1.9281272292137144, Close=491134000.0, Position=-3, OrderPending=True
# 2009-09-10: Close
# 2009-09-10: Sell 1 shares at 491134000.0
# 2009-09-10: Sentiment=-1.9281272292137144, Close=491134000.0, Position=-3, OrderPending=True
# 2009-09-10: Close
# 2009-09-10: Sell 1 shares at 491134000.0
# 2009-09-10: Sentiment=-1.9281272292137144, Close=491134000.0, Position=-3, OrderPending=True
# 2009-09-10: Close
# 2009-09-10: Sell 1 shares at 491134000.0
# 2009-09-11: Sentiment=-1.9281272292137144, Close=348961200.0, Position=-4, OrderPending=True
# 2009-09-11: Close
# 2009-09-11: Sell 1 shares at 348961200.0
# 2009-09-11: Sentiment=-1.9281272292137144, Close=348961200.0, Position=-4, OrderPending=True
# 2009-09-11: Close
# 2009-09-11: Sell 1 shares at 348961200.0
# 2009-09-11: Sentiment=-1.9281272292137144, Close=348961200.0, Position=-4, OrderPending=True
# 2009-09-11: Close
# 2009-09-11: Sell 1 shares at 348961200.0
# 2009-09-11: Sentiment=-1.9281272292137144, Close=348961200.0, Position=-4, OrderPending=True
# 2009-09-11: Close
# 2009-09-11: Sell 1 shares at 348961200.0
# 2009-09-14: Sentiment=-1.9281272292137144, Close=322011200.0, Position=-1, OrderPending=True
# 2009-09-14: Close
# 2009-09-14: Sell 1 shares at 322011200.0
# 2009-09-14: Sentiment=-1.9281272292137144, Close=322011200.0, Position=-1, OrderPending=True
# 2009-09-14: Close
# 2009-09-14: Sell 1 shares at 322011200.0
# 2009-09-14: Sentiment=-1.9281272292137144, Close=322011200.0, Position=-1, OrderPending=True
# 2009-09-14: Close
# 2009-09-14: Sell 1 shares at 322011200.0
# 2009-09-14: Sentiment=-1.9281272292137144, Close=322011200.0, Position=-1, OrderPending=True
# 2009-09-14: Close
# 2009-09-14: Sell 1 shares at 322011200.0
# 2009-09-15: Sentiment=-1.9281272292137144, Close=426470800.0, Position=-1, OrderPending=True
# 2009-09-15: Close
# 2009-09-15: Sell 1 shares at 426470800.0
# 2009-09-15: Sentiment=-1.9281272292137144, Close=426470800.0, Position=-1, OrderPending=True
# 2009-09-15: Close
# 2009-09-15: Sell 1 shares at 426470800.0
# 2009-09-15: Sentiment=-1.9281272292137144, Close=426470800.0, Position=-1, OrderPending=True
# 2009-09-15: Close
# 2009-09-15: Sell 1 shares at 426470800.0
# 2009-09-15: Sentiment=-1.9281272292137144, Close=426470800.0, Position=-1, OrderPending=True
# 2009-09-15: Close
# 2009-09-15: Sell 1 shares at 426470800.0
# 2009-09-16: Sentiment=-1.9281272292137144, Close=754023200.0, Position=-1, OrderPending=True
# 2009-09-16: Close
# 2009-09-16: Sell 1 shares at 754023200.0
# 2009-09-16: Sentiment=-1.9281272292137144, Close=754023200.0, Position=-1, OrderPending=True
# 2009-09-16: Close
# 2009-09-16: Sell 1 shares at 754023200.0
# 2009-09-16: Sentiment=-1.9281272292137144, Close=754023200.0, Position=-1, OrderPending=True
# 2009-09-16: Close
# 2009-09-16: Sell 1 shares at 754023200.0
# 2009-09-16: Sentiment=-1.9281272292137144, Close=754023200.0, Position=-1, OrderPending=True
# 2009-09-16: Close
# 2009-09-16: Sell 1 shares at 754023200.0
# 2009-09-17: Sentiment=0.9996110796928406, Close=810572000.0, Position=-1, OrderPending=True
# 2009-09-17: Close
# 2009-09-17: Buy 1 shares at 810572000.0
# 2009-09-17: Sentiment=0.9996110796928406, Close=810572000.0, Position=-1, OrderPending=True
# 2009-09-17: Close
# 2009-09-17: Buy 1 shares at 810572000.0
# 2009-09-17: Sentiment=0.9996110796928406, Close=810572000.0, Position=-1, OrderPending=True
# 2009-09-17: Close
# 2009-09-17: Buy 1 shares at 810572000.0
# 2009-09-17: Sentiment=0.9996110796928406, Close=810572000.0, Position=-1, OrderPending=True
# 2009-09-17: Close
# 2009-09-17: Buy 1 shares at 810572000.0
# 2009-09-18: Sentiment=0.9996110796928406, Close=601582800.0, Position=-1, OrderPending=True
# 2009-09-18: Close
# 2009-09-18: Buy 1 shares at 601582800.0
# 2009-09-18: Sentiment=0.9996110796928406, Close=601582800.0, Position=-1, OrderPending=True
# 2009-09-18: Close
# 2009-09-18: Buy 1 shares at 601582800.0
# 2009-09-18: Sentiment=0.9996110796928406, Close=601582800.0, Position=-1, OrderPending=True
# 2009-09-18: Close
# 2009-09-18: Buy 1 shares at 601582800.0
# 2009-09-18: Sentiment=0.9996110796928406, Close=601582800.0, Position=-1, OrderPending=True
# 2009-09-18: Close
# 2009-09-18: Buy 1 shares at 601582800.0
# 2009-09-21: Sentiment=0.9996110796928406, Close=437715600.0, Position=0, OrderPending=True
# 2009-09-21: Close
# 2009-09-21: Buy 1 shares at 437715600.0
# 2009-09-21: Sentiment=0.9996110796928406, Close=437715600.0, Position=0, OrderPending=True
# 2009-09-21: Close
# 2009-09-21: Buy 1 shares at 437715600.0
# 2009-09-21: Sentiment=0.9996110796928406, Close=437715600.0, Position=0, OrderPending=True
# 2009-09-21: Close
# 2009-09-21: Buy 1 shares at 437715600.0
# 2009-09-21: Sentiment=0.9996110796928406, Close=437715600.0, Position=0, OrderPending=True
# 2009-09-21: Close
# 2009-09-21: Buy 1 shares at 437715600.0
# 2009-09-22: Sentiment=-0.999087691307068, Close=356753600.0, Position=0, OrderPending=True
# 2009-09-22: Close
# 2009-09-22: Sell 1 shares at 356753600.0
# 2009-09-22: Sentiment=-0.999087691307068, Close=356753600.0, Position=0, OrderPending=True
# 2009-09-22: Close
# 2009-09-22: Sell 1 shares at 356753600.0
# 2009-09-22: Sentiment=-0.999087691307068, Close=356753600.0, Position=0, OrderPending=True
# 2009-09-22: Close
# 2009-09-22: Sell 1 shares at 356753600.0
# 2009-09-22: Sentiment=-0.999087691307068, Close=356753600.0, Position=0, OrderPending=True
# 2009-09-22: Close
# 2009-09-22: Sell 1 shares at 356753600.0
# 2009-09-30: Sell 1 shares at 539585200.0
# 2009-09-30: Sentiment=-0.9799783825874328, Close=539585200.0, Position=-4, OrderPending=True
# 2009-09-30: Close
# 2009-09-30: Sell 1 shares at 539585200.0
# 2009-09-30: Sentiment=-0.9799783825874328, Close=539585200.0, Position=-4, OrderPending=True
# 2009-09-30: Close
# 2009-09-30: Sell 1 shares at 539585200.0
# 2009-09-30: Sentiment=-0.9799783825874328, Close=539585200.0, Position=-4, OrderPending=True
# 2009-09-30: Close
# 2009-09-30: Sell 1 shares at 539585200.0
# 2009-10-01: Sentiment=-0.9799783825874328, Close=524711600.0, Position=-1, OrderPending=True
# 2009-10-01: Close
# 2009-10-01: Sell 1 shares at 524711600.0
# 2009-10-01: Sentiment=-0.9799783825874328, Close=524711600.0, Position=-1, OrderPending=True
# 2009-10-01: Close
# 2009-10-01: Sell 1 shares at 524711600.0
# 2009-10-01: Sentiment=-0.9799783825874328, Close=524711600.0, Position=-1, OrderPending=True
# 2009-10-01: Close
# 2009-10-01: Sell 1 shares at 524711600.0
# 2009-10-01: Sentiment=-0.9799783825874328, Close=524711600.0, Position=-1, OrderPending=True
# 2009-10-01: Close
# 2009-10-01: Sell 1 shares at 524711600.0
# 2009-10-02: Sentiment=-0.9799783825874328, Close=553308000.0, Position=-1, OrderPending=True
# 2009-10-02: Close
# 2009-10-02: Sell 1 shares at 553308000.0
# 2009-10-02: Sentiment=-0.9799783825874328, Close=553308000.0, Position=-1, OrderPending=True
# 2009-10-02: Close
# 2009-10-02: Sell 1 shares at 553308000.0
# 2009-10-02: Sentiment=-0.9799783825874328, Close=553308000.0, Position=-1, OrderPending=True
# 2009-10-02: Close
# 2009-10-02: Sell 1 shares at 553308000.0
# 2009-10-02: Sentiment=-0.9799783825874328, Close=553308000.0, Position=-1, OrderPending=True
# 2009-10-02: Close
# 2009-10-02: Sell 1 shares at 553308000.0
# 2009-10-05: Sentiment=-0.9799783825874328, Close=423133200.0, Position=-1, OrderPending=True
# 2009-10-05: Close
# 2009-10-05: Sell 1 shares at 423133200.0
# 2009-10-05: Sentiment=-0.9799783825874328, Close=423133200.0, Position=-1, OrderPending=True
# 2009-10-05: Close
# 2009-10-05: Sell 1 shares at 423133200.0
# 2009-10-05: Sentiment=-0.9799783825874328, Close=423133200.0, Position=-1, OrderPending=True
# 2009-10-05: Close
# 2009-10-05: Sell 1 shares at 423133200.0
# 2009-10-05: Sentiment=-0.9799783825874328, Close=423133200.0, Position=-1, OrderPending=True
# 2009-10-05: Close
# 2009-10-05: Sell 1 shares at 423133200.0
# 2009-10-06: Sentiment=-0.9799783825874328, Close=605085600.0, Position=-1, OrderPending=True
# 2009-10-06: Close
# 2009-10-06: Sell 1 shares at 605085600.0
# 2009-10-06: Sentiment=-0.9799783825874328, Close=605085600.0, Position=-1, OrderPending=True
# 2009-10-06: Close
# 2009-10-06: Sell 1 shares at 605085600.0
# 2009-10-06: Sentiment=-0.9799783825874328, Close=605085600.0, Position=-1, OrderPending=True
# 2009-10-06: Close
# 2009-10-06: Sell 1 shares at 605085600.0
# 2009-10-06: Sentiment=-0.9799783825874328, Close=605085600.0, Position=-1, OrderPending=True
# 2009-10-06: Close
# 2009-10-06: Sell 1 shares at 605085600.0
# 2009-10-07: Sentiment=-0.9799783825874328, Close=465668000.0, Position=-1, OrderPending=True
# 2009-10-07: Close
# 2009-10-07: Sell 1 shares at 465668000.0
# 2009-10-07: Sentiment=-0.9799783825874328, Close=465668000.0, Position=-1, OrderPending=True
# 2009-10-07: Close
# 2009-10-07: Sell 1 shares at 465668000.0
# 2009-10-07: Sentiment=-0.9799783825874328, Close=465668000.0, Position=-1, OrderPending=True
# 2009-10-07: Close
# 2009-10-07: Sell 1 shares at 465668000.0
# 2009-10-07: Sentiment=-0.9799783825874328, Close=465668000.0, Position=-1, OrderPending=True
# 2009-10-07: Close
# 2009-10-07: Sell 1 shares at 465668000.0
# 2009-10-08: Sentiment=-0.9799783825874328, Close=438211200.0, Position=-1, OrderPending=True
# 2009-10-08: Close
# 2009-10-08: Sell 1 shares at 438211200.0
# 2009-10-08: Sentiment=-0.9799783825874328, Close=438211200.0, Position=-1, OrderPending=True
# 2009-10-08: Close
# 2009-10-08: Sell 1 shares at 438211200.0
# 2009-10-08: Sentiment=-0.9799783825874328, Close=438211200.0, Position=-1, OrderPending=True
# 2009-10-08: Close
# 2009-10-08: Sell 1 shares at 438211200.0
# 2009-10-08: Sentiment=-0.9799783825874328, Close=438211200.0, Position=-1, OrderPending=True
# 2009-10-08: Close
# 2009-10-08: Sell 1 shares at 438211200.0
# 2009-10-09: Sentiment=-0.9799783825874328, Close=293272000.0, Position=-1, OrderPending=True
# 2009-10-09: Close
# 2009-10-09: Sell 1 shares at 293272000.0
# 2009-10-09: Sentiment=-0.9799783825874328, Close=293272000.0, Position=-1, OrderPending=True
# 2009-10-09: Close
# 2009-10-09: Sell 1 shares at 293272000.0
# 2009-10-09: Sentiment=-0.9799783825874328, Close=293272000.0, Position=-1, OrderPending=True
# 2009-10-09: Close
# 2009-10-09: Sell 1 shares at 293272000.0
# 2009-10-09: Sentiment=-0.9799783825874328, Close=293272000.0, Position=-1, OrderPending=True
# 2009-10-09: Close
# 2009-10-09: Sell 1 shares at 293272000.0
# 2009-10-12: Sentiment=-0.9799783825874328, Close=288024800.0, Position=-1, OrderPending=True
# 2009-10-12: Close
# 2009-10-12: Sell 1 shares at 288024800.0
# 2009-10-12: Sentiment=-0.9799783825874328, Close=288024800.0, Position=-1, OrderPending=True
# 2009-10-12: Close
# 2009-10-12: Sell 1 shares at 288024800.0
# 2009-10-12: Sentiment=-0.9799783825874328, Close=288024800.0, Position=-1, OrderPending=True
# 2009-10-12: Close
# 2009-10-12: Sell 1 shares at 288024800.0
# 2009-10-12: Sentiment=-0.9799783825874328, Close=288024800.0, Position=-1, OrderPending=True
# 2009-10-12: Close
# 2009-10-12: Sell 1 shares at 288024800.0
# 2009-10-13: Sentiment=-0.9799783825874328, Close=348020400.0, Position=-1, OrderPending=True
# 2009-10-13: Close
# 2009-10-13: Sell 1 shares at 348020400.0
# 2009-10-13: Sentiment=-0.9799783825874328, Close=348020400.0, Position=-1, OrderPending=True
# 2009-10-13: Close
# 2009-10-13: Sell 1 shares at 348020400.0
# 2009-10-13: Sentiment=-0.9799783825874328, Close=348020400.0, Position=-1, OrderPending=True
# 2009-10-13: Close
# 2009-10-13: Sell 1 shares at 348020400.0
# 2009-10-13: Sentiment=-0.9799783825874328, Close=348020400.0, Position=-1, OrderPending=True
# 2009-10-13: Close
# 2009-10-13: Sell 1 shares at 348020400.0
# 2009-10-14: Sentiment=-0.9799783825874328, Close=375510800.0, Position=-1, OrderPending=True
# 2009-10-14: Close
# 2009-10-14: Sell 1 shares at 375510800.0
# 2009-10-14: Sentiment=-0.9799783825874328, Close=375510800.0, Position=-1, OrderPending=True
# 2009-10-14: Close
# 2009-10-14: Sell 1 shares at 375510800.0
# 2009-10-14: Sentiment=-0.9799783825874328, Close=375510800.0, Position=-1, OrderPending=True
# 2009-10-14: Close
# 2009-10-14: Sell 1 shares at 375510800.0
# 2009-10-14: Sentiment=-0.9799783825874328, Close=375510800.0, Position=-1, OrderPending=True
# 2009-10-14: Close
# 2009-10-14: Sell 1 shares at 375510800.0
# 2009-10-15: Sentiment=-0.9799783825874328, Close=373556400.0, Position=-1, OrderPending=True
# 2009-10-15: Close
# 2009-10-15: Sell 1 shares at 373556400.0
# 2009-10-15: Sentiment=-0.9799783825874328, Close=373556400.0, Position=-1, OrderPending=True
# 2009-10-15: Close
# 2009-10-15: Sell 1 shares at 373556400.0
# 2009-10-15: Sentiment=-0.9799783825874328, Close=373556400.0, Position=-1, OrderPending=True
# 2009-10-15: Close
# 2009-10-15: Sell 1 shares at 373556400.0
# 2009-10-15: Sentiment=-0.9799783825874328, Close=373556400.0, Position=-1, OrderPending=True
# 2009-10-15: Close
# 2009-10-15: Sell 1 shares at 373556400.0
# 2009-10-16: Sentiment=-0.9799783825874328, Close=431426800.0, Position=-1, OrderPending=True
# 2009-10-16: Close
# 2009-10-16: Sell 1 shares at 431426800.0
# 2009-10-16: Sentiment=-0.9799783825874328, Close=431426800.0, Position=-1, OrderPending=True
# 2009-10-16: Close
# 2009-10-16: Sell 1 shares at 431426800.0
# 2009-10-16: Sentiment=-0.9799783825874328, Close=431426800.0, Position=-1, OrderPending=True
# 2009-10-16: Close
# 2009-10-16: Sell 1 shares at 431426800.0
# 2009-10-16: Sentiment=-0.9799783825874328, Close=431426800.0, Position=-1, OrderPending=True
# 2009-10-16: Close
# 2009-10-16: Sell 1 shares at 431426800.0
# 2009-10-19: Sentiment=-1.559576153755188, Close=942230800.0, Position=-1, OrderPending=True
# 2009-10-19: Close
# 2009-10-19: Sell 1 shares at 942230800.0
# 2009-10-19: Sentiment=-1.559576153755188, Close=942230800.0, Position=-1, OrderPending=True
# 2009-10-19: Close
# 2009-10-19: Sell 1 shares at 942230800.0
# 2010-05-21: Sentiment=-0.0539720654487609, Close=1223891200.0, Position=-1, OrderPending=True
# 2010-05-21: Close
# 2010-05-21: No trade (Sentiment=-0.0539720654487609 within threshold)
# 2010-05-21: Sentiment=-0.0539720654487609, Close=1223891200.0, Position=-1, OrderPending=True
# 2010-05-21: Close
# 2010-05-21: No trade (Sentiment=-0.0539720654487609 within threshold)
# 2010-05-21: Sentiment=-0.0539720654487609, Close=1223891200.0, Position=-1, OrderPending=True
# 2010-05-21: Close
# 2010-05-21: No trade (Sentiment=-0.0539720654487609 within threshold)
# 2010-05-24: Sentiment=0.9988211989402772, Close=754238800.0, Position=0, OrderPending=True
# 2010-05-24: Close
# 2010-05-24: Buy 1 shares at 754238800.0
# 2010-05-24: Sentiment=0.9988211989402772, Close=754238800.0, Position=0, OrderPending=True
# 2010-05-24: Close
# 2010-05-24: Buy 1 shares at 754238800.0
# 2010-05-24: Sentiment=0.9988211989402772, Close=754238800.0, Position=0, OrderPending=True
# 2010-05-24: Close
# 2010-05-24: Buy 1 shares at 754238800.0
# 2010-05-24: Sentiment=0.9988211989402772, Close=754238800.0, Position=0, OrderPending=True
# 2010-05-24: Close
# 2010-05-24: Buy 1 shares at 754238800.0
# 2010-05-25: Sentiment=0.9988211989402772, Close=1048006400.0, Position=1, OrderPending=True
# 2010-05-25: Close
# 2010-05-25: Buy 1 shares at 1048006400.0
# 2010-05-25: Sentiment=0.9988211989402772, Close=1048006400.0, Position=1, OrderPending=True
# 2010-05-25: Close
# 2010-05-25: Buy 1 shares at 1048006400.0
# 2010-05-25: Sentiment=0.9988211989402772, Close=1048006400.0, Position=1, OrderPending=True
# 2010-05-25: Close
# 2010-05-25: Buy 1 shares at 1048006400.0
# 2010-05-25: Sentiment=0.9988211989402772, Close=1048006400.0, Position=1, OrderPending=True
# 2010-05-25: Close
# 2010-05-25: Buy 1 shares at 1048006400.0
# 2010-05-26: Sentiment=-0.9834721088409424, Close=850654000.0, Position=1, OrderPending=True
# 2010-05-26: Close
# 2010-05-26: Sell 1 shares at 850654000.0
# 2010-05-26: Sentiment=-0.9834721088409424, Close=850654000.0, Position=1, OrderPending=True
# 2010-05-26: Close
# 2010-05-26: Sell 1 shares at 850654000.0
# 2010-05-26: Sentiment=-0.9834721088409424, Close=850654000.0, Position=1, OrderPending=True
# 2010-05-26: Close
# 2010-05-26: Sell 1 shares at 850654000.0
# 2010-05-26: Sentiment=-0.9834721088409424, Close=850654000.0, Position=1, OrderPending=True
# 2010-05-26: Close
# 2010-05-26: Sell 1 shares at 850654000.0
# 2010-05-27: Sentiment=-0.9965444207191468, Close=666282400.0, Position=-7, OrderPending=True
# 2010-05-27: Close
# 2010-05-27: Sell 1 shares at 666282400.0
# 2010-05-27: Sentiment=-0.9965444207191468, Close=666282400.0, Position=-7, OrderPending=True
# 2010-05-27: Close
# 2010-05-27: Sell 1 shares at 666282400.0
# 2010-05-27: Sentiment=-0.9965444207191468, Close=666282400.0, Position=-7, OrderPending=True
# 2010-05-27: Close
# 2010-05-27: Sell 1 shares at 666282400.0
# 2010-05-27: Sentiment=-0.9965444207191468, Close=666282400.0, Position=-7, OrderPending=True
# 2010-05-27: Close
# 2010-05-27: Sell 1 shares at 666282400.0
# 2010-05-28: Sentiment=-0.8981152176856995, Close=815614800.0, Position=-1, OrderPending=True
# 2010-05-28: Close
# 2010-05-28: Sell 1 shares at 815614800.0
# 2010-05-28: Sentiment=-0.8981152176856995, Close=815614800.0, Position=-1, OrderPending=True
# 2010-05-28: Close
# 2010-05-28: Sell 1 shares at 815614800.0
# 2010-05-28: Sentiment=-0.8981152176856995, Close=815614800.0, Position=-1, OrderPending=True
# 2010-05-28: Close
# 2010-05-28: Sell 1 shares at 815614800.0
# 2010-05-28: Sentiment=-0.8981152176856995, Close=815614800.0, Position=-1, OrderPending=True
# 2010-05-28: Close
# 2010-05-28: Sell 1 shares at 815614800.0
# 2010-06-01: Sentiment=-0.8981152176856995, Close=876472800.0, Position=-5, OrderPending=True
# 2010-06-01: Close
# 2010-06-01: Sell 1 shares at 876472800.0
# 2010-06-01: Sentiment=-0.8981152176856995, Close=876472800.0, Position=-5, OrderPending=True
# 2010-06-01: Close
# 2010-06-01: Sell 1 shares at 876472800.0
# 2010-06-01: Sentiment=-0.8981152176856995, Close=876472800.0, Position=-5, OrderPending=True
# 2010-06-01: Close
# 2010-06-01: Sell 1 shares at 876472800.0
# 2010-06-01: Sentiment=-0.8981152176856995, Close=876472800.0, Position=-5, OrderPending=True
# 2010-06-01: Close
# 2010-06-01: Sell 1 shares at 876472800.0
# 2010-06-02: Sentiment=1.1680834889411926, Close=688548000.0, Position=-6, OrderPending=True
# 2010-06-02: Close
# 2010-06-02: Buy 1 shares at 688548000.0
# 2010-06-02: Sentiment=1.1680834889411926, Close=688548000.0, Position=-6, OrderPending=True
# 2010-06-02: Close
# 2010-06-02: Buy 1 shares at 688548000.0
# 2010-06-02: Sentiment=1.1680834889411926, Close=688548000.0, Position=-6, OrderPending=True
# 2010-06-02: Close
# 2010-06-02: Buy 1 shares at 688548000.0
# 2010-06-02: Sentiment=1.1680834889411926, Close=688548000.0, Position=-6, OrderPending=True
# 2010-06-02: Close
# 2010-06-02: Buy 1 shares at 688548000.0
# 2010-06-03: Sentiment=-1.946943402290344, Close=650106800.0, Position=1, OrderPending=True
# 2010-06-03: Close
# 2010-06-03: Sell 1 shares at 650106800.0
# 2010-06-03: Sentiment=-1.946943402290344, Close=650106800.0, Position=1, OrderPending=True
# 2010-06-03: Close
# 2010-06-03: Sell 1 shares at 650106800.0
# 2010-06-03: Sentiment=-1.946943402290344, Close=650106800.0, Position=1, OrderPending=True
# 2010-06-03: Close
# 2010-06-03: Sell 1 shares at 650106800.0
# 2010-06-03: Sentiment=-1.946943402290344, Close=650106800.0, Position=1, OrderPending=True
# 2010-06-03: Close
# 2010-06-03: Sell 1 shares at 650106800.0
# 2010-06-04: Sentiment=-1.946943402290344, Close=758304400.0, Position=-7, OrderPending=True
# 2010-06-04: Close
# 2010-06-04: Sell 1 shares at 758304400.0
# 2010-06-04: Sentiment=-1.946943402290344, Close=758304400.0, Position=-7, OrderPending=True
# 2010-06-04: Close
# 2010-06-04: Sell 1 shares at 758304400.0
# 2010-06-04: Sentiment=-1.946943402290344, Close=758304400.0, Position=-7, OrderPending=True
# 2010-06-04: Close
# 2010-06-04: Sell 1 shares at 758304400.0
# 2010-06-04: Sentiment=-1.946943402290344, Close=758304400.0, Position=-7, OrderPending=True
# 2010-06-04: Close
# 2010-06-04: Sell 1 shares at 758304400.0
# 2010-06-07: Sentiment=1.9353589415550232, Close=886942000.0, Position=-1, OrderPending=True
# 2010-06-07: Close
# 2010-06-07: Buy 1 shares at 886942000.0
# 2010-06-07: Sentiment=1.9353589415550232, Close=886942000.0, Position=-1, OrderPending=True
# 2010-06-07: Close
# 2010-06-07: Buy 1 shares at 886942000.0
# 2010-06-07: Sentiment=1.9353589415550232, Close=886942000.0, Position=-1, OrderPending=True
# 2010-06-07: Close
# 2010-06-07: Buy 1 shares at 886942000.0
# 2010-06-07: Sentiment=1.9353589415550232, Close=886942000.0, Position=-1, OrderPending=True
# 2010-06-07: Close
# 2010-06-07: Buy 1 shares at 886942000.0
# 2010-06-08: Sentiment=1.9353589415550232, Close=1000770400.0, Position=0, OrderPending=True
# 2010-06-08: Close
# 2010-06-08: Buy 1 shares at 1000770400.0
# 2010-06-08: Sentiment=1.9353589415550232, Close=1000770400.0, Position=0, OrderPending=True
# 2010-06-08: Close
# 2010-06-08: Buy 1 shares at 1000770400.0
# 2010-06-08: Sentiment=1.9353589415550232, Close=1000770400.0, Position=0, OrderPending=True
# 2010-06-08: Close
# 2010-06-08: Buy 1 shares at 1000770400.0
# 2010-06-08: Sentiment=1.9353589415550232, Close=1000770400.0, Position=0, OrderPending=True
# 2010-06-08: Close
# 2010-06-08: Buy 1 shares at 1000770400.0
# 2010-06-09: Sentiment=-0.9995869994163512, Close=854630000.0, Position=0, OrderPending=True
# 2010-06-09: Close
# 2010-06-09: Sell 1 shares at 854630000.0
# 2010-06-09: Sentiment=-0.9995869994163512, Close=854630000.0, Position=0, OrderPending=True
# 2010-06-09: Close
# 2010-06-09: Sell 1 shares at 854630000.0
# 2010-06-09: Sentiment=-0.9995869994163512, Close=854630000.0, Position=0, OrderPending=True
# 2010-06-09: Close
# 2010-06-09: Sell 1 shares at 854630000.0
# 2010-06-09: Sentiment=-0.9995869994163512, Close=854630000.0, Position=0, OrderPending=True
# 2010-06-09: Close
# 2010-06-09: Sell 1 shares at 854630000.0
# OrderedDict({'sharperatio': 0.9998015708167252})
# OrderedDict({'rtot': 7.8470583596245085, 'ravg': 0.0363289738871505, 'rnorm': 9459.697771834015, 'rnorm100': 945969.7771834015})
# Initial Portfolio Value: %.2f 100000, commission: 0.001
# Final Portfolio Value: 255819793.93
# Sharpe Ratio: 0.9998015708167252
# Total Return: 7.8470583596245085
# Total Trades: 1
