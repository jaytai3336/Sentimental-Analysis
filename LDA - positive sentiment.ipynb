# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import gensim
from gensim import corpora
from gensim.models.ldamodel import LdaModel
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
pyLDAvis.enable_notebook()

import matplotlib.pyplot as plt
import ipywidgets
nltk.download('punkt')
nltk.download('stopwords')


# Load the dataset
df = pd.read_csv('data/Training Data/Labeled-headlines.csv', encoding='ISO-8859-1', on_bad_lines='skip', header=None)  # Ensure your CSV file has columns like 'title' and 'content'
df = df[df.iloc[:, 0] == 'positive'].dropna()
# Print first few rows of the dataset
df.head()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Jay
# [nltk_data]     Tai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Jay
# [nltk_data]     Tai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#           0                                                  1
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...
# 5  positive  FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# 6  positive  For the last quarter of 2010 , Componenta 's n...
# 7  positive  In the third quarter of 2010 , net sales incre...

# %%
# Define a function to preprocess the text
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    tokens = [word for word in tokens if word.isalpha()]  # Remove non-alphabetic characters
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    return tokens

# Apply the function to preprocess the 'data' column
df['processed_content'] = df[1].apply(preprocess_text)

# Preview the preprocessed text
df['processed_content'].head()
# Out:
# 3    [new, production, plant, company, would, incre...
# 4    [according, company, updated, strategy, years,...
# 5    [financing, aspocomp, growth, aspocomp, aggres...
# 6    [last, quarter, componenta, net, sales, double...
# 7    [third, quarter, net, sales, increased, eur, m...
# Name: processed_content, dtype: object

# %%
# Create a dictionary and corpus for LDA
dictionary = corpora.Dictionary(df['processed_content'])
corpus = [dictionary.doc2bow(text) for text in df['processed_content']]

# Preview the corpus
print(corpus[:2])  # List of tuples (term_id, term_frequency)
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 3), (6, 1), (7, 1), (8, 1), (9, 1), (10, 2), (11, 1), (12, 1), (13, 1), (14, 1), (15, 2)], [(1, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 2), (21, 1), (22, 1), (23, 1), (24, 2), (25, 1), (26, 1), (27, 1), (28, 1)]]

# %%
from collections import Counter

# Step 1: Calculate word frequencies
# Sum word counts across all documents
word_freq = Counter()
for doc in corpus:
    for word_id, count in doc:
        word = dictionary[word_id]
        word_freq[word] += count

# Get the top N most frequent words (e.g., top 20)
top_n = 100
most_common_words = word_freq.most_common(top_n)

# Print the most frequent words
print(f"Top {top_n} most frequent words:")
for word, freq in most_common_words:
    print(f"Word: {word}, Frequency: {freq}")
# Out:
# Top 100 most frequent words:
# Word: eur, Frequency: 449
# Word: mn, Frequency: 241
# Word: company, Frequency: 240
# Word: said, Frequency: 230
# Word: finnish, Frequency: 198
# Word: net, Frequency: 196
# Word: sales, Frequency: 192
# Word: profit, Frequency: 191
# Word: million, Frequency: 170
# Word: period, Frequency: 139
# Word: year, Frequency: 139
# Word: mln, Frequency: 128
# Word: operating, Frequency: 122
# Word: quarter, Frequency: 107
# Word: oyj, Frequency: 97
# Word: group, Frequency: 96
# Word: rose, Frequency: 94
# Word: increased, Frequency: 89
# Word: new, Frequency: 82
# Word: increase, Frequency: 76
# Word: finland, Frequency: 75
# Word: first, Frequency: 73
# Word: loss, Frequency: 72
# Word: compared, Frequency: 71
# Word: services, Frequency: 69
# Word: euro, Frequency: 67
# Word: business, Frequency: 66
# Word: share, Frequency: 66
# Word: percent, Frequency: 66
# Word: corresponding, Frequency: 65
# Word: market, Frequency: 64
# Word: also, Frequency: 63
# Word: today, Frequency: 60
# Word: agreement, Frequency: 59
# Word: signed, Frequency: 58
# Word: contract, Frequency: 58
# Word: operations, Frequency: 54
# Word: technology, Frequency: 53
# Word: hel, Frequency: 50
# Word: per, Frequency: 47
# Word: solutions, Frequency: 44
# Word: order, Frequency: 44
# Word: mobile, Frequency: 44
# Word: growth, Frequency: 42
# Word: nokia, Frequency: 41
# Word: last, Frequency: 40
# Word: service, Frequency: 39
# Word: corporation, Frequency: 38
# Word: products, Frequency: 38
# Word: maker, Frequency: 38
# Word: customers, Frequency: 36
# Word: helsinki, Frequency: 36
# Word: earlier, Frequency: 35
# Word: supply, Frequency: 33
# Word: second, Frequency: 33
# Word: bank, Frequency: 33
# Word: grew, Frequency: 33
# Word: months, Frequency: 33
# Word: financial, Frequency: 32
# Word: companies, Frequency: 32
# Word: awarded, Frequency: 32
# Word: according, Frequency: 31
# Word: russia, Frequency: 31
# Word: equipment, Frequency: 31
# Word: third, Frequency: 30
# Word: us, Frequency: 30
# Word: plant, Frequency: 29
# Word: usd, Frequency: 29
# Word: expected, Frequency: 28
# Word: construction, Frequency: 28
# Word: omx, Frequency: 28
# Word: nine, Frequency: 28
# Word: production, Frequency: 27
# Word: line, Frequency: 27
# Word: earnings, Frequency: 27
# Word: pct, Frequency: 27
# Word: paper, Frequency: 27
# Word: result, Frequency: 26
# Word: eps, Frequency: 26
# Word: ceo, Frequency: 26
# Word: provider, Frequency: 25
# Word: systems, Frequency: 25
# Word: positive, Frequency: 25
# Word: billion, Frequency: 24
# Word: acquisition, Frequency: 24
# Word: well, Frequency: 24
# Word: global, Frequency: 24
# Word: two, Frequency: 24
# Word: management, Frequency: 24
# Word: steel, Frequency: 23
# Word: significant, Frequency: 23
# Word: software, Frequency: 23
# Word: news, Frequency: 22
# Word: orders, Frequency: 22
# Word: says, Frequency: 22
# Word: industry, Frequency: 22
# Word: leading, Frequency: 22
# Word: announced, Frequency: 21
# Word: investment, Frequency: 21
# Word: euros, Frequency: 21

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from nltk.util import ngrams

# Generate bigrams and trigrams
def generate_ngrams(tokens, n):
    return list(ngrams(tokens, n))

# Collect all bigrams and trigrams
bigrams = []
trigrams = []
for tokens in df['processed_content']:
    bigrams.extend(generate_ngrams(tokens, 2))
    trigrams.extend(generate_ngrams(tokens, 3))

# Count frequencies
bigram_freq = Counter(bigrams)
trigram_freq = Counter(trigrams)

# Convert tuples to readable strings
bigram_freq = {(' '.join(bigram)): freq for bigram, freq in bigram_freq.items()}
trigram_freq = {(' '.join(trigram)): freq for trigram, freq in trigram_freq.items()}

# Get top N bigrams and trigrams
top_n = 100
top_bigrams = sorted(bigram_freq.items(), key=lambda x: x[1], reverse=True)[:top_n]
top_trigrams = sorted(trigram_freq.items(), key=lambda x: x[1], reverse=True)[:top_n]

# Print results
print(f"Top {top_n} Bigrams:")
for bigram, freq in top_bigrams:
    print(f"Bigram: {bigram}, Frequency: {freq}")

print(f"\nTop {top_n} Trigrams:")
for trigram, freq in top_trigrams:
    print(f"Trigram: {trigram}, Frequency: {freq}")
# Out:
# Top 100 Bigrams:
# Bigram: eur mn, Frequency: 231
# Bigram: net sales, Frequency: 102
# Bigram: operating profit, Frequency: 101
# Bigram: eur million, Frequency: 90
# Bigram: mn eur, Frequency: 79
# Bigram: corresponding period, Frequency: 63
# Bigram: net profit, Frequency: 52
# Bigram: rose eur, Frequency: 47
# Bigram: euro mln, Frequency: 45
# Bigram: mln euro, Frequency: 44
# Bigram: said today, Frequency: 44
# Bigram: profit rose, Frequency: 43
# Bigram: oyj hel, Frequency: 36
# Bigram: mn corresponding, Frequency: 33
# Bigram: per share, Frequency: 32
# Bigram: hel said, Frequency: 30
# Bigram: net loss, Frequency: 30
# Bigram: mln eur, Frequency: 29
# Bigram: year earlier, Frequency: 28
# Bigram: last year, Frequency: 26
# Bigram: first quarter, Frequency: 26
# Bigram: nine months, Frequency: 26
# Bigram: second quarter, Frequency: 25
# Bigram: third quarter, Frequency: 24
# Bigram: increased eur, Frequency: 24
# Bigram: first nine, Frequency: 23
# Bigram: million usd, Frequency: 23
# Bigram: period increased, Frequency: 20
# Bigram: oyj said, Frequency: 20
# Bigram: company said, Frequency: 19
# Bigram: eur eur, Frequency: 18
# Bigram: earnings per, Frequency: 18
# Bigram: mn compared, Frequency: 18
# Bigram: loss eur, Frequency: 18
# Bigram: sales increased, Frequency: 17
# Bigram: million eur, Frequency: 17
# Bigram: adp news, Frequency: 17
# Bigram: totalled eur, Frequency: 16
# Bigram: compared corresponding, Frequency: 16
# Bigram: signed agreement, Frequency: 16
# Bigram: increased respectively, Frequency: 16
# Bigram: respectively compared, Frequency: 16
# Bigram: today net, Frequency: 16
# Bigram: profit eur, Frequency: 15
# Bigram: totaled eur, Frequency: 15
# Bigram: million liters, Frequency: 15
# Bigram: cash flow, Frequency: 15
# Bigram: oyj omx, Frequency: 15
# Bigram: market share, Frequency: 14
# Bigram: year ago, Frequency: 14
# Bigram: loss narrowed, Frequency: 14
# Bigram: period year, Frequency: 13
# Bigram: pretax profit, Frequency: 13
# Bigram: million euros, Frequency: 13
# Bigram: omx helsinki, Frequency: 13
# Bigram: fourth quarter, Frequency: 13
# Bigram: sales period, Frequency: 13
# Bigram: share eps, Frequency: 13
# Bigram: quarter eur, Frequency: 12
# Bigram: profit period, Frequency: 11
# Bigram: percent million, Frequency: 11
# Bigram: sales rose, Frequency: 11
# Bigram: profit net, Frequency: 11
# Bigram: press release, Frequency: 11
# Bigram: compared eur, Frequency: 11
# Bigram: compared loss, Frequency: 10
# Bigram: said net, Frequency: 10
# Bigram: previous year, Frequency: 10
# Bigram: grew percent, Frequency: 10
# Bigram: million million, Frequency: 10
# Bigram: expects net, Frequency: 10
# Bigram: equipment maker, Frequency: 10
# Bigram: awarded contract, Frequency: 10
# Bigram: stora enso, Frequency: 9
# Bigram: sales million, Frequency: 9
# Bigram: sales eur, Frequency: 9
# Bigram: mn first, Frequency: 9
# Bigram: mobile phone, Frequency: 9
# Bigram: sales increase, Frequency: 9
# Bigram: mln first, Frequency: 9
# Bigram: narrowed eur, Frequency: 9
# Bigram: profit increased, Frequency: 8
# Bigram: helsinki afx, Frequency: 8
# Bigram: viking line, Frequency: 8
# Bigram: said yesterday, Frequency: 8
# Bigram: company also, Frequency: 8
# Bigram: per cent, Frequency: 8
# Bigram: beer sales, Frequency: 8
# Bigram: mn year, Frequency: 8
# Bigram: rose mln, Frequency: 8
# Bigram: technology company, Frequency: 8
# Bigram: eur year, Frequency: 8
# Bigram: cost savings, Frequency: 8
# Bigram: expected increase, Frequency: 7
# Bigram: last quarter, Frequency: 7
# Bigram: quarter net, Frequency: 7
# Bigram: profit totalled, Frequency: 7
# Bigram: neste oil, Frequency: 7
# Bigram: solutions provider, Frequency: 7
# Bigram: company net, Frequency: 7
#
# Top 100 Trigrams:
# Trigram: eur mn eur, Frequency: 78
# Trigram: mn eur mn, Frequency: 77
# Trigram: mln euro mln, Frequency: 43
# Trigram: eur mn corresponding, Frequency: 33
# Trigram: mn corresponding period, Frequency: 33
# Trigram: rose eur mn, Frequency: 29
# Trigram: profit rose eur, Frequency: 28
# Trigram: first nine months, Frequency: 23
# Trigram: eur million usd, Frequency: 23
# Trigram: oyj hel said, Frequency: 22
# Trigram: increased eur mn, Frequency: 21
# Trigram: operating profit rose, Frequency: 21
# Trigram: hel said today, Frequency: 20
# Trigram: net profit rose, Frequency: 18
# Trigram: earnings per share, Frequency: 18
# Trigram: eur mn compared, Frequency: 17
# Trigram: eur million eur, Frequency: 16
# Trigram: period increased respectively, Frequency: 16
# Trigram: increased respectively compared, Frequency: 16
# Trigram: said today net, Frequency: 16
# Trigram: totalled eur mn, Frequency: 15
# Trigram: million eur million, Frequency: 15
# Trigram: compared corresponding period, Frequency: 14
# Trigram: net sales increased, Frequency: 13
# Trigram: per share eps, Frequency: 13
# Trigram: net loss narrowed, Frequency: 13
# Trigram: respectively compared corresponding, Frequency: 12
# Trigram: net sales period, Frequency: 12
# Trigram: sales period increased, Frequency: 12
# Trigram: totaled eur mn, Frequency: 11
# Trigram: operating profit net, Frequency: 11
# Trigram: profit net sales, Frequency: 11
# Trigram: loss eur mn, Frequency: 11
# Trigram: operating profit eur, Frequency: 10
# Trigram: profit eur mn, Frequency: 10
# Trigram: expects net sales, Frequency: 10
# Trigram: eur mn first, Frequency: 9
# Trigram: rose eur million, Frequency: 9
# Trigram: today net profit, Frequency: 9
# Trigram: euro mln first, Frequency: 9
# Trigram: net sales eur, Frequency: 8
# Trigram: said net profit, Frequency: 8
# Trigram: mn first quarter, Frequency: 8
# Trigram: quarter eur mn, Frequency: 8
# Trigram: eur mn year, Frequency: 8
# Trigram: loss narrowed eur, Frequency: 8
# Trigram: period year earlier, Frequency: 7
# Trigram: sales increased eur, Frequency: 7
# Trigram: profit totalled eur, Frequency: 7
# Trigram: operating profit increased, Frequency: 7
# Trigram: hel said yesterday, Frequency: 7
# Trigram: net sales rose, Frequency: 7
# Trigram: net sales increase, Frequency: 7
# Trigram: profit rose mln, Frequency: 7
# Trigram: mln first nine, Frequency: 7
# Trigram: euro mln period, Frequency: 7
# Trigram: mln mln euro, Frequency: 7
# Trigram: million usd first, Frequency: 7
# Trigram: usd first nine, Frequency: 7
# Trigram: cash flow operations, Frequency: 7
# Trigram: mn compared eur, Frequency: 7
# Trigram: compared eur mn, Frequency: 7
# Trigram: loss per share, Frequency: 7
# Trigram: mn compared loss, Frequency: 7
# Trigram: compared loss eur, Frequency: 7
# Trigram: quarter net sales, Frequency: 6
# Trigram: nokia siemens networks, Frequency: 6
# Trigram: rose eur eur, Frequency: 6
# Trigram: period year ago, Frequency: 6
# Trigram: profit totaled eur, Frequency: 6
# Trigram: omx helsinki said, Frequency: 6
# Trigram: euro mln mln, Frequency: 6
# Trigram: net interest income, Frequency: 6
# Trigram: adp news nov, Frequency: 6
# Trigram: news nov finnish, Frequency: 6
# Trigram: oyj omx said, Frequency: 6
# Trigram: omx said today, Frequency: 6
# Trigram: today net loss, Frequency: 6
# Trigram: eur million period, Frequency: 6
# Trigram: operating profit totalled, Frequency: 5
# Trigram: profit increased eur, Frequency: 5
# Trigram: operating profit period, Frequency: 5
# Trigram: stock exchange release, Frequency: 5
# Trigram: sales eur mn, Frequency: 5
# Trigram: grew percent million, Frequency: 5
# Trigram: eur mn second, Frequency: 5
# Trigram: mn second quarter, Frequency: 5
# Trigram: corresponding period year, Frequency: 5
# Trigram: operating profit totaled, Frequency: 5
# Trigram: share eps rose, Frequency: 5
# Trigram: eps rose eur, Frequency: 5
# Trigram: rose mln euro, Frequency: 5
# Trigram: finnish lifting equipment, Frequency: 5
# Trigram: lifting equipment maker, Frequency: 5
# Trigram: oyj omx helsinki, Frequency: 5
# Trigram: adp news feb, Frequency: 5
# Trigram: news feb finnish, Frequency: 5
# Trigram: nine months eur, Frequency: 5
# Trigram: percent million euros, Frequency: 5
# Trigram: per share eur, Frequency: 5

# %%
# Train the LDA model
lda_model = LdaModel(corpus=corpus, num_topics=15, id2word=dictionary, passes=10)

# Print the topics with top words
lda_model.show_topics()
# Out:
# Coherence Score: 0.486020841409667

# %%
from gensim.models.coherencemodel import CoherenceModel

# Calculate Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=df['processed_content'], dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print(f'Coherence Score: {coherence_lda}')
# Out:
# Coherence Score: 0.3813695599602054

# %%
# Visualize the topics using pyLDAvis
vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.save_html(vis, 'data/LDA positive sentiment.html')
